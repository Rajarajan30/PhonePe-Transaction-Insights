# %%
# !pip install GitPython

# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# fatal: destination path 'pulse' already exists and is not an empty directory.

# %%
import os

# List contents of the pulse directory
os.listdir('pulse')
# Out:
# ['.git', '.gitignore', 'data', 'LICENSE', 'README.md']

# %%
import pandas as pd
import json
import os

# %%
# this is to direct the path to get state data
# aggregated transaction

path = r"C:\Users\rajar\project phone pay\pulse\data\aggregated\transaction\country\india\state"
Agg_state_list_transaction = os.listdir(path)
Agg_state_list_transaction

# -----------------------------------------------------------------------

col_nam = {'State': [], 'Year' : [], 'Quarter' : [], 'Transaction_Type' : [], 'Transaction_Count' : [], 'Transaction_Amount' : []}

for i in Agg_state_list_transaction:
    p_i = os.path.join(path, i)          # path + i + '\\'
    Agg_yr = os.listdir(p_i)
    
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)         # p_i + j + '\\'
        Agg_qu = os.listdir(p_j)
        
        for k in Agg_qu:
            p_k = os.path.join(p_j, k)     # p_j + k
            Data = open(p_k, 'r')  # read the json file
            D = json.load(Data) 
            Data.close()
            for z in D['data']['transactionData']:
                Name = z['name']
                Count = z['paymentInstruments'][0]['count']
                Amount = z['paymentInstruments'][0]['amount']
                
                col_nam['Transaction_Type'].append(Name)
                col_nam['Transaction_Count'].append(Count)
                col_nam['Transaction_Amount'].append(Amount)
                col_nam['State'].append(i)
                col_nam['Year'].append(j)
                col_nam['Quarter'].append(int(k.strip(' .json')))
# succesfully created data frame

Agg_data_transaction = pd.DataFrame(col_nam)

# %%
Agg_data_transaction
# Out:
#                           State  Year  Quarter          Transaction_Type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 5029                west-bengal  2024        4         Merchant payments
# 5030                west-bengal  2024        4     Peer-to-peer payments
# 5031                west-bengal  2024        4  Recharge & bill payments
# 5032                west-bengal  2024        4        Financial Services
# 5033                west-bengal  2024        4                    Others
#
#       Transaction_Count  Transaction_Amount
# 0                  4200        1.845307e+06
# ...

# %%
# aggregated user
# this is to direct the path to get state data

path = r"C:\Users\rajar\project phone pay\pulse\data\aggregated\user\country\india\state"
Agg_state_list = os.listdir(path)
Agg_state_list

# -----------------------------------------------------------------------

col_nam = {'State': [], 'Year' : [], 'Quarter' : [], 'Brand' : [], 'Transaction_Count' : [], 'Percentage' : []}

for i in Agg_state_list:
    p_i = os.path.join(path, i)          # path + i + '\\'
    Agg_yr = os.listdir(p_i)
    
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)         # p_i + j + '\\'
        Agg_qu = os.listdir(p_j)
        
        for k in Agg_qu:
            p_k = os.path.join(p_j, k)     # p_j + k
            Data = open(p_k, 'r')  # read the json file
            D = json.load(Data) 
            Data.close()
            
            if D['data'] and D['data']['usersByDevice']:
                for z in D['data']['usersByDevice']:
                    Name = z['brand']
                    Count = z['count']
                    Amount = z['percentage']
                
                    col_nam['Brand'].append(Name)
                    col_nam['Transaction_Count'].append(Count)
                    col_nam['Percentage'].append(Amount)
                    col_nam['State'].append(i)
                    col_nam['Year'].append(j)
                    col_nam['Quarter'].append(int(k.strip(' .json')))
# succesfully created data frame

Agg_data_user = pd.DataFrame(col_nam)

# %%
Agg_data_user
# Out:
#                           State  Year  Quarter    Brand  Transaction_Count  \
# 0     andaman-&-nicobar-islands  2018        1   Xiaomi               1665
# 1     andaman-&-nicobar-islands  2018        1  Samsung               1445
# 2     andaman-&-nicobar-islands  2018        1     Vivo                982
# 3     andaman-&-nicobar-islands  2018        1     Oppo                501
# 4     andaman-&-nicobar-islands  2018        1  OnePlus                332
# ...                         ...   ...      ...      ...                ...
# 6727                west-bengal  2022        1   Lenovo             330017
# 6728                west-bengal  2022        1  Infinix             284678
# 6729                west-bengal  2022        1     Asus             280347
# 6730                west-bengal  2022        1    Apple             277752
# 6731                west-bengal  2022        1   Others            2196334
#
#       Percentage
# 0       0.247033
# 1       0.214392
# ...

# %%
# aggregated insurance
# this is to direct the path to get state data

path = r"C:\Users\rajar\project phone pay\pulse\data\aggregated\insurance\country\india\state"
Agg_state_list_insurance = os.listdir(path)
Agg_state_list_insurance

# -----------------------------------------------------------------------

col_nam = {'State': [], 'Year' : [], 'Quarter' : [], 'Insurance_type' : [], 'Transaction_Count' : [], 'Transaction_Amount' : []}

for i in Agg_state_list_insurance:
    p_i = os.path.join(path, i)          # path + i + '\\'
    Agg_yr = os.listdir(p_i)
    
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)         # p_i + j + '\\'
        Agg_qu = os.listdir(p_j)
        
        for k in Agg_qu:
            p_k = os.path.join(p_j, k)     # p_j + k
            Data = open(p_k, 'r')  # read the json file
            D = json.load(Data) 
            Data.close()
            for z in D['data']['transactionData']:
                Name = z['name']
                Count = z['paymentInstruments'][0]['count']
                Amount = z['paymentInstruments'][0]['amount']
                
                col_nam['Insurance_type'].append(Name)
                col_nam['Transaction_Count'].append(Count)
                col_nam['Transaction_Amount'].append(Amount)
                col_nam['State'].append(i)
                col_nam['Year'].append(j)
                col_nam['Quarter'].append(int(k.strip(' .json')))
# succesfully created data frame

Agg_data_insurance = pd.DataFrame(col_nam)

# %%
Agg_data_insurance
# Out:
#                          State  Year  Quarter Insurance_type  \
# 0    andaman-&-nicobar-islands  2020        2      Insurance
# 1    andaman-&-nicobar-islands  2020        3      Insurance
# 2    andaman-&-nicobar-islands  2020        4      Insurance
# 3    andaman-&-nicobar-islands  2021        1      Insurance
# 4    andaman-&-nicobar-islands  2021        2      Insurance
# ..                         ...   ...      ...            ...
# 677                west-bengal  2023        4      Insurance
# 678                west-bengal  2024        1      Insurance
# 679                west-bengal  2024        2      Insurance
# 680                west-bengal  2024        3      Insurance
# 681                west-bengal  2024        4      Insurance
#
#      Transaction_Count  Transaction_Amount
# 0                    6              1360.0
# 1                   41             15380.0
# 2                  124            157975.0
# 3                  225            244266.0
# ...

# %%
# map transaction
# this is to direct the path to get state data

path = r"C:\Users\rajar\project phone pay\pulse\data\map\transaction\hover\country\india\state"
Agg_state_list_map_transaction = os.listdir(path)


# -----------------------------------------------------------------------

col_nam = {'State': [], 'Year' : [], 'Quarter' : [], 'District' : [], 'Transaction_Count' : [], 'Transaction_Amount' : []}

for i in Agg_state_list_map_transaction:
    p_i = os.path.join(path, i)          # path + i + '\\'
    Agg_yr = os.listdir(p_i)
    
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)         # p_i + j + '\\'
        Agg_qu = os.listdir(p_j)
        
        for k in Agg_qu:
            p_k = os.path.join(p_j, k)     # p_j + k
            Data = open(p_k, 'r')  # read the json file
            D = json.load(Data) 
            Data.close()
            for z in D['data']['hoverDataList']:
                Name = z['name']
                Count = z['metric'][0]['count']
                Amount = z['metric'][0]['amount']
                
                col_nam['District'].append(Name)
                col_nam['Transaction_Count'].append(Count)
                col_nam['Transaction_Amount'].append(Amount)
                col_nam['State'].append(i)
                col_nam['Year'].append(j)
                col_nam['Quarter'].append(int(k.strip(' .json')))
# succesfully created data frame

Agg_data_map_transaction = pd.DataFrame(col_nam)

# %%
Agg_data_map_transaction
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 20599                west-bengal  2024        4
# 20600                west-bengal  2024        4
# 20601                west-bengal  2024        4
# 20602                west-bengal  2024        4
# 20603                west-bengal  2024        4
#
#                                 District  Transaction_Count  \
# 0      north and middle andaman district                442
# 1                 south andaman district               5688
# 2                      nicobars district                528
# 3      north and middle andaman district                825
# 4                 south andaman district               9395
# ...

# %%
# map user
# this is to direct the path to get state data

path = r"C:\Users\rajar\project phone pay\pulse\data\map\user\hover\country\india\state"
Agg_state_list_map_user = os.listdir(path)


# -----------------------------------------------------------------------

col_nam = {'State': [], 'Year' : [], 'Quarter' : [], 'District' : [], 'Registered_Users' : [], 'App_Opens' : []}

for i in Agg_state_list_map_user:
    p_i = os.path.join(path, i)          # path + i + '\\'
    Agg_yr = os.listdir(p_i)
    
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)         # p_i + j + '\\'
        Agg_qu = os.listdir(p_j)
        
        for k in Agg_qu:
            p_k = os.path.join(p_j, k)     # p_j + k
            Data = open(p_k, 'r')  # read the json file
            D = json.load(Data) 
            Data.close()
            
            for z in D['data']['hoverData'].items():
                dis = z[0]
                Users = z[1]['registeredUsers']
                App = z[1]['appOpens']
                
                col_nam['District'].append(dis)
                col_nam['Registered_Users'].append(Users)
                col_nam['App_Opens'].append(App)
                col_nam['State'].append(i)
                col_nam['Year'].append(j)
                col_nam['Quarter'].append(int(k.strip(' .json')))
# succesfully created data frame

Agg_data_map_user = pd.DataFrame(col_nam)

# %%
Agg_data_map_user
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 20603                west-bengal  2024        4
# 20604                west-bengal  2024        4
# 20605                west-bengal  2024        4
# 20606                west-bengal  2024        4
# 20607                west-bengal  2024        4
#
#                                 District  Registered_Users  App_Opens
# 0      north and middle andaman district               632          0
# 1                 south andaman district              5846          0
# 2                      nicobars district               262          0
# 3      north and middle andaman district               911          0
# ...

# %%
# map insurance
# this is to direct the path to get state data

path = r"C:\Users\rajar\project phone pay\pulse\data\map\insurance\hover\country\india\state"
Agg_state_list_map_insurance = os.listdir(path)


# -----------------------------------------------------------------------

col_nam = {'State': [], 'Year' : [], 'Quarter' : [], 'District' : [], 'Transaction_Count' : [], 'Transaction_Amount' : []}

for i in Agg_state_list_map_insurance:
    p_i = os.path.join(path, i)          # path + i + '\\'
    Agg_yr = os.listdir(p_i)
    
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)         # p_i + j + '\\'
        Agg_qu = os.listdir(p_j)
        
        for k in Agg_qu:
            p_k = os.path.join(p_j, k)     # p_j + k
            Data = open(p_k, 'r')  # read the json file
            D = json.load(Data) 
            Data.close()
            for z in D['data']['hoverDataList']:
                Name = z['name']
                Count = z['metric'][0]['count']
                Amount = z['metric'][0]['amount']
                
                col_nam['District'].append(Name)
                col_nam['Transaction_Count'].append(Count)
                col_nam['Transaction_Amount'].append(Amount)
                col_nam['State'].append(i)
                col_nam['Year'].append(j)
                col_nam['Quarter'].append(int(k.strip(' .json')))
# succesfully created data frame

Agg_data_map_insurance = pd.DataFrame(col_nam)

# %%
Agg_data_map_insurance
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2020        2
# 1      andaman-&-nicobar-islands  2020        2
# 2      andaman-&-nicobar-islands  2020        3
# 3      andaman-&-nicobar-islands  2020        3
# 4      andaman-&-nicobar-islands  2020        3
# ...                          ...   ...      ...
# 13871                west-bengal  2024        4
# 13872                west-bengal  2024        4
# 13873                west-bengal  2024        4
# 13874                west-bengal  2024        4
# 13875                west-bengal  2024        4
#
#                                 District  Transaction_Count  \
# 0                 south andaman district                  3
# 1                      nicobars district                  3
# 2      north and middle andaman district                  1
# 3                 south andaman district                 35
# 4                      nicobars district                  5
# ...

# %%
# top

# top trancation
# this is to direct the path to get state data

path = r"C:\Users\rajar\project phone pay\pulse\data\top\transaction\country\india\state"
Agg_state_list_top_trancation = os.listdir(path)


# -----------------------------------------------------------------------

# col_nam = {'Year' : [], 'Quater' : [],'State': [], 'District' : [], 'Transaction_Count' : [], 'Transaction_Amount' : []}

rows = []

for i in Agg_state_list_top_trancation:
    p_i = os.path.join(path, i)          # path + i + '\\'
    Agg_yr = os.listdir(p_i)
    
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)         # p_i + j + '\\'
        Agg_qu = os.listdir(p_j)
        
        for k in Agg_qu:
            p_k = os.path.join(p_j, k)     # p_j + k
            Data = open(p_k, 'r')  # read the json file
            D = json.load(Data) 
            Data.close()

            for level in ['states', 'districts', 'pincodes']:
                level_data = D['data'].get(level)    # geting level from loaded data
                if isinstance(level_data, list):    # avoid null error
                    for z in level_data:
                        rows.append({
                            'Year': j,
                            'Quarter': int(k.strip('.json')),
                            'State': i,
                            'Level': level[:-1].capitalize(),  # 'states' -> 'State'
                            'Entity_Name': z['entityName'],
                            'Transaction_Count': z['metric']['count'],
                            'Transaction_Amount': z['metric']['amount']
            })
# succesfully created data frame

Agg_data_top_trancation = pd.DataFrame(rows)

# %%
Agg_data_top_trancation
# Out:
#        Year  Quarter                      State     Level  \
# 0      2018        1  andaman-&-nicobar-islands  District
# 1      2018        1  andaman-&-nicobar-islands  District
# 2      2018        1  andaman-&-nicobar-islands  District
# 3      2018        1  andaman-&-nicobar-islands   Pincode
# 4      2018        1  andaman-&-nicobar-islands   Pincode
# ...     ...      ...                        ...       ...
# 18290  2024        4                west-bengal   Pincode
# 18291  2024        4                west-bengal   Pincode
# 18292  2024        4                west-bengal   Pincode
# 18293  2024        4                west-bengal   Pincode
# 18294  2024        4                west-bengal   Pincode
#
#                     Entity_Name  Transaction_Count  Transaction_Amount
# 0                 south andaman               5688        1.256025e+07
# 1                      nicobars                528        1.139849e+06
# ...

# %%
# top user
# this is to direct the path to get state data

path = r"C:\Users\rajar\project phone pay\pulse\data\top\user\country\india\state"
Agg_state_list_top_user = os.listdir(path)


# -----------------------------------------------------------------------

rows = []

for i in Agg_state_list_top_user:
    p_i = os.path.join(path, i)          # path + i + '\\'
    Agg_yr = os.listdir(p_i)
    
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)         # p_i + j + '\\'
        Agg_qu = os.listdir(p_j)
        
        for k in Agg_qu:
            p_k = os.path.join(p_j, k)     # p_j + k
            Data = open(p_k, 'r')  # read the json file
            D = json.load(Data) 
            Data.close()

            for level in ['states', 'districts', 'pincodes']:
                level_data = D['data'].get(level)    # geting level from loaded data
                if isinstance(level_data, list):    # avoid null error
                    for z in level_data:
                        rows.append({
                            'Year': j,
                            'Quarter': int(k.strip('.json')),
                            'State': i,
                            'Level': level[:-1].capitalize(),  # 'states' -> 'State'
                            'Entity_Name': z['name'],
                            'RegisteredUsers': z['registeredUsers']
            })
# succesfully created data frame

Agg_data_top_user = pd.DataFrame(rows)

# %%
Agg_data_top_user
# Out:
#        Year  Quarter                      State     Level  \
# 0      2018        1  andaman-&-nicobar-islands  District
# 1      2018        1  andaman-&-nicobar-islands  District
# 2      2018        1  andaman-&-nicobar-islands  District
# 3      2018        1  andaman-&-nicobar-islands   Pincode
# 4      2018        1  andaman-&-nicobar-islands   Pincode
# ...     ...      ...                        ...       ...
# 18291  2024        4                west-bengal   Pincode
# 18292  2024        4                west-bengal   Pincode
# 18293  2024        4                west-bengal   Pincode
# 18294  2024        4                west-bengal   Pincode
# 18295  2024        4                west-bengal   Pincode
#
#                     Entity_Name  RegisteredUsers
# 0                 south andaman             5846
# 1      north and middle andaman              632
# 2                      nicobars              262
# 3                        744103             1608
# ...

# %%
# top insurance
# this is to direct the path to get state data

path = r"C:\Users\rajar\project phone pay\pulse\data\top\insurance\country\india\state"
Agg_state_list_top_insurance = os.listdir(path)


# -----------------------------------------------------------------------

rows = []

for i in Agg_state_list_top_insurance:
    p_i = os.path.join(path, i)          # path + i + '\\'
    Agg_yr = os.listdir(p_i)
    
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)         # p_i + j + '\\'
        Agg_qu = os.listdir(p_j)
        
        for k in Agg_qu:
            p_k = os.path.join(p_j, k)     # p_j + k
            Data = open(p_k, 'r')  # read the json file
            D = json.load(Data) 
            Data.close()

            for level in ['states', 'districts', 'pincodes']:
                level_data = D['data'].get(level)    # geting level from loaded data
                if isinstance(level_data, list):    # avoid null error
                    for z in level_data:
                        rows.append({
                            'Year': j,
                            'Quarter': int(k.strip('.json')),
                            'State': i,
                            'Level': level[:-1].capitalize(),  # 'states' -> 'State'
                            'Entity_Name': z['entityName'],
                            'Transaction_Count': z['metric']['count'],
                            'Transaction_Amount': z['metric']['amount']
            })
# succesfully created data frame

Agg_data_top_insurance = pd.DataFrame(rows)

# %%
Agg_data_top_insurance
# Out:
#        Year  Quarter                      State     Level    Entity_Name  \
# 0      2020        2  andaman-&-nicobar-islands  District       nicobars
# 1      2020        2  andaman-&-nicobar-islands  District  south andaman
# 2      2020        2  andaman-&-nicobar-islands   Pincode         744301
# 3      2020        2  andaman-&-nicobar-islands   Pincode         744104
# 4      2020        2  andaman-&-nicobar-islands   Pincode         744101
# ...     ...      ...                        ...       ...            ...
# 12271  2024        4                west-bengal   Pincode         711101
# 12272  2024        4                west-bengal   Pincode         700091
# 12273  2024        4                west-bengal   Pincode         700150
# 12274  2024        4                west-bengal   Pincode         700039
# 12275  2024        4                west-bengal   Pincode         700156
#
#        Transaction_Count  Transaction_Amount
# 0                      3               565.0
# ...

# %%
Agg_data_transaction.to_csv('Agg_data_transaction.csv', index = False)
print("sucess")
# Out:
# sucess

# %%
# Connect Python to DataBase

import mysql.connector as db

# %%
user = "raja"
passcode = "raja"
host = "localhost"
db_name = "phonepe"

# %%
db_connection = db.connect(

                host = host,
                user = user,
                password = passcode,
                database = db_name
)

# %%
db_connection

# %%
curr = db_connection.cursor()  #-> curr defining

# %%
# creating table in db

table1 = """
CREATE TABLE IF NOT EXISTS agg_trans (
    State varchar(50),
    Year int,
    Quarter int,
    Transaction_Type varchar(40),
    Transaction_Count bigint,
    Transaction_Amount float

);
"""

curr.execute(table1)
db_connection.commit()

# %%
Agg_data_user.columns
# Out:
# Index(['State', 'Year', 'Quarter', 'Brand', 'Transaction_Count', 'Percentage'], dtype='object')

# %%
for _, row in Agg_data_transaction.iterrows():
    insert_t1 = '''INSERT INTO agg_trans (State, Year, Quarter, Transaction_Type, Transaction_Count, Transaction_Amount)
                                                            values(%s,%s,%s,%s,%s,%s)'''
    values = (row["State"],
              row["Year"],
              row["Quarter"],
              row["Transaction_Type"],
              row["Transaction_Count"],
              row["Transaction_Amount"]
              )
    curr.execute(insert_t1,values)
    db_connection.commit()

# %%
tab2 = """
CREATE TABLE IF NOT EXISTS agg_user (
State varchar(50),
Year int,
Quarter int,
Brand varchar(50),
Transaction_Count bigint,
Percentage float

);
"""

curr.execute(tab2)
db_connection.commit()

# %%
for _, row in Agg_data_user.iterrows():
    t2 = """ insert into agg_user(State, Year, Quarter, Brand, Transaction_Count, Percentage)
    values(%s,%s,%s,%s,%s,%s)
    """
    values = (row['State'],
              row['Year'],
              row['Quarter'],
              row['Brand'],
              row['Transaction_Count'],
              row['Percentage']
             )
    curr.execute(t2, values)
    db_connection.commit()

# %%
tab3 = """
create table phonepe.agg_ins
(
State varchar(50),
Year int,
Quarter int,
Insurance_Type varchar(30),
Transaction_Count bigint,
Transaction_Amount float
);
"""
curr.execute(tab3)
db_connection.commit()

# %%
Agg_data_insurance.columns
# Out:
# Index(['State', 'Year', 'Quarter', 'Insurance_type', 'Transaction_Count',
#        'Transaction_Amount'],
#       dtype='object')

# %%
for _, row in Agg_data_insurance.iterrows():
    t3 = """insert into agg_ins(State, Year, Quarter, Insurance_type, Transaction_Count, Transaction_Amount)
    values(%s,%s,%s,%s,%s,%s)
    """
    values = (row['State'],
              row['Year'],
              row['Quarter'],
              row['Insurance_type'],
              row['Transaction_Count'],
              row['Transaction_Amount']
             )
    curr.execute(t3, values)
    db_connection.commit()

# %%
tab4 = """
create table phonepe.map_trans
(
State varchar(50),
Year int,
Quarter int,
District varchar(100),
Transaction_Count bigint,
Transaction_Amount float
);
"""
curr.execute(tab4)
db_connection.commit()

# %%
Agg_data_map_transaction.columns
# Out:
# Index(['State', 'Year', 'Quarter', 'District', 'Transaction_Count',
#        'Transaction_Amount'],
#       dtype='object')

# %%
for _, row in Agg_data_map_transaction.iterrows():
     curr.execute("""
     insert into phonepe.map_trans(State, Year, Quarter, District, Transaction_Count, Transaction_Amount)
     values(%s,%s,%s,%s,%s,%s)
    """,(row['State'],
         row['Year'],
         row['Quarter'],
         row['District'],
         row['Transaction_Count'],
         row['Transaction_Amount']))
    
db_connection.commit()

# %%
tab5 = """
create table phonepe.map_user
(
State varchar(50),
Year int,
Quarter int,
District varchar(100),
Registered_Users bigint,
App_Opens bigint
);
"""
curr.execute(tab5)
db_connection.commit()

# %%
Agg_data_map_user.columns
# Out:
# Index(['State', 'Year', 'Quarter', 'District', 'Registered_Users',
#        'App_Opens'],
#       dtype='object')

# %%
for _, row in Agg_data_map_user.iterrows():
     curr.execute("""
     insert into phonepe.map_user(State, Year, Quarter, District, Registered_Users, App_Opens)
     values(%s,%s,%s,%s,%s,%s)
    """,(row['State'],
         row['Year'],
         row['Quarter'],
         row['District'],
         row['Registered_Users'],
         row['App_Opens']))
    
db_connection.commit()

# %%
tab6 = """
create table phonepe.map_ins
(
State varchar(50),
Year int,
Quarter int,
District varchar(100),
Transaction_Count bigint,
Transaction_Amount float
);
"""
curr.execute(tab6)
db_connection.commit()

# %%
Agg_data_map_insurance.columns
# Out:
# Index(['State', 'Year', 'Quarter', 'District', 'Transaction_Count',
#        'Transaction_Amount'],
#       dtype='object')

# %%
for _, row in Agg_data_map_insurance.iterrows():
     curr.execute("""
     insert into phonepe.map_ins(State, Year, Quarter, District, Transaction_Count, Transaction_Amount)
     values(%s,%s,%s,%s,%s,%s)
    """,(row['State'],
         row['Year'],
         row['Quarter'],
         row['District'],
         row['Transaction_Count'],
         row['Transaction_Amount']))
    
db_connection.commit()

# %%
tab7 = """
create table phonepe.top_trans
(
Year int,
Quarter int,
State varchar(50),
Level varchar(50),
Entity_Name varchar(50),
Transaction_Count bigint,
Transaction_Amount FLOAT 
);
"""
curr.execute(tab7)
db_connection.commit()

# %%
Agg_data_top_trancation.columns
# Out:
# Index(['Year', 'Quarter', 'State', 'Level', 'Entity_Name', 'Transaction_Count',
#        'Transaction_Amount'],
#       dtype='object')

# %%
for _, row in Agg_data_top_trancation.iterrows():
     curr.execute("""
     insert into phonepe.top_trans(Year, Quarter, State, Level, Entity_Name, Transaction_Count, Transaction_Amount)
     values(%s,%s,%s,%s,%s,%s,%s)
    """,(row['Year'],
         row['Quarter'],
         row['State'],
         row['Level'],
         row['Entity_Name'],
         row['Transaction_Count'],
         row['Transaction_Amount']))
    
db_connection.commit()

# %%
tab8 = """
create table phonepe.top_user
(
Year int,
Quarter int,
State varchar(50),
Level varchar(50),
Entity_Name varchar(50),
RegisteredUsers bigint 
);
"""
curr.execute(tab8)
db_connection.commit()

# %%
Agg_data_top_user.columns
# Out:
# Index(['Year', 'Quarter', 'State', 'Level', 'Entity_Name', 'RegisteredUsers'], dtype='object')

# %%
for _, row in Agg_data_top_user.iterrows():
     curr.execute("""
     insert into phonepe.top_user(Year, Quarter, State, Level, Entity_Name, RegisteredUsers)
     values(%s,%s,%s,%s,%s,%s)
    """,(row['Year'],
         row['Quarter'],
         row['State'],
         row['Level'],
         row['Entity_Name'],
         row['RegisteredUsers']))
    
db_connection.commit()

# %%
tab9 = """
create table phonepe.top_ins
(
Year int,
Quarter int,
State varchar(50),
Level varchar(50),
Entity_Name varchar(50),
Transaction_Count bigint,
Transaction_Amount FLOAT 
);
"""
curr.execute(tab9)
db_connection.commit()

# %%
Agg_data_top_insurance.columns
# Out:
# Index(['Year', 'Quarter', 'State', 'Level', 'Entity_Name', 'Transaction_Count',
#        'Transaction_Amount'],
#       dtype='object')

# %%
for _, row in Agg_data_top_insurance.iterrows():
     curr.execute("""
     insert into phonepe.top_ins(Year, Quarter, State, Level, Entity_Name, Transaction_Count, Transaction_Amount)
     values(%s,%s,%s,%s,%s,%s,%s)
    """,(row['Year'],
         row['Quarter'],
         row['State'],
         row['Level'],
         row['Entity_Name'],
         row['Transaction_Count'],
         row['Transaction_Amount']))
    
db_connection.commit()

# %%
curr.close()
db_connection.close()
